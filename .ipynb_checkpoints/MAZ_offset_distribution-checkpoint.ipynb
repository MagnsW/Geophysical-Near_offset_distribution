# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
from scipy import stats

# %%
path = './input_X_maz/'
#file = '469-0-562-60-120_Ch32'
#file = '120deg-10x75'
file = 'Axxis_Full'
filename = path + file +'.txt'

# %%
f = open(filename)
lines = f.read().splitlines()
f.close()
for i, line in enumerate(lines):
    if i < 10:
        print(i, line)

# %%
column_names = ['ShotNo', 'StrNo', 'RecNo', 'Offset', 'MidPtX', 'MidPtY', 'DipSrc', 'DipRec', 'AzSrc']

# %%
rowstoskip = 2

# %%
df_raw = pd.read_csv(filename, names=column_names, usecols=['Offset', 'MidPtX', 'MidPtY', 'AzSrc'], skiprows=rowstoskip, delim_whitespace=True)

# %%
len(df_raw)
# Out:
# 56422118

# %%
mx_min, mx_max = 12000, 13000
my_min, my_max = 12000, 13000

# %%
df_filt = df_raw[(df_raw['MidPtX'] >= mx_min) & (df_raw['MidPtY'] >= my_min) & (df_raw['MidPtX'] <= mx_max) & (df_raw['MidPtY'] <= my_max)]

# %%
len(df_filt)
# Out:
# 1575930

# %%
df_filt['OffsetY'] = df_filt.apply(lambda row: row.Offset*np.cos(np.deg2rad(row.AzSrc)), axis=1)
df_filt['OffsetX'] = df_filt.apply(lambda row: row.Offset*np.sin(np.deg2rad(row.AzSrc)), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_filt
# Out:
#            Offset   MidPtX   MidPtY       AzSrc      OffsetY      OffsetX
# 3403887   6195.53  12002.5  12137.5  162.384000 -5904.998012  1874.990789
# 3404069   6111.44  12002.5  12287.5  165.066000 -5905.015868  1574.956021
# 3404251   6041.08  12002.5  12437.5  167.816000 -5905.003883  1274.981063
# 3404433   5984.95  12002.5  12587.5  170.624000 -5904.993994   975.024325
# 3404615   5943.45  12002.5  12737.5  173.479000 -5904.997648   674.981981
# 3404797   5916.90  12002.5  12887.5  176.366000 -5905.002842   375.029390
# 3405525   6298.59  12008.8  12012.5  159.314000 -5892.522253  2224.953368
# 3405707   6198.97  12008.8  12162.5  161.908000 -5892.487350  1925.051139
# 3405889   6112.46  12008.8  12312.5  164.582000 -5892.484360  1625.052405
# 3406071   6039.63  12008.8  12462.5  167.327000 -5892.492750  1325.013107
# 3406253   5980.98  12008.8  12612.5  170.132000 -5892.492572  1025.013682
# 3406435   5936.93  12008.8  12762.5  172.986000 -5892.500056   724.969592
# 3406617   5907.81  12008.8  12912.5  175.875000 -5892.505767   424.964448
# 3407527   6156.71  12015.0  12112.5  162.757000 -5880.003852  1825.002116
# 3407709   6074.54  12015.0  12262.5  165.460000 -5879.988316  1525.048727
# 3407891   6006.25  12015.0  12412.5  168.232000 -5880.007323  1224.970587
# 3408073   5952.31  12015.0  12562.5  171.060000 -5879.999057   924.989418
# 3408255   5913.12  12015.0  12712.5  173.933000 -5880.000514   624.965672
# 3408437   5888.97  12015.0  12862.5  176.836000 -5879.993094   325.036724
# 3409347   6159.80  12021.2  12137.5  162.278000 -5867.484663  1875.035939
# 3409529   6075.21  12021.2  12287.5  164.974000 -5867.488112  1575.042795
# 3409711   6004.43  12021.2  12437.5  167.740000 -5867.493327  1275.030070
# 3409893   5947.96  12021.2  12587.5  170.565000 -5867.497231   975.040722
# 3410075   5906.20  12021.2  12737.5  173.437000 -5867.495382   675.052876
stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], None, 'count', bins=[xx,yy])

# %%
#ret.statistic

# %%
def fold_plot(data, title, incx, incy):
    data[data==0] = np.nan
    sns.set_style('dark')
    f, ax = plt.subplots(figsize=(18, 12))
    ax = sns.heatmap(data, cmap='jet')
    ax.invert_yaxis()
    plt.title(title)
    plt.xlabel('Bin X (inc: '+ str(incx)+'m')
    plt.ylabel('Bin Y (inc: '+ str(incy)+'m)');

# %%
fold_plot(ret_fold.statistic.T, file+' - Fold', binsize_x, binsize_y)

# %%
ret_fold.statistic.max()
# Out:
# nan

# %%
ret_minoffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], df_filt['Offset'], statistic='min', bins=[xx,yy])

# %%
fold_plot(ret_minoffs.statistic.T, file+' - Minimum Offset', binsize_x, binsize_y)

# %%
ret_maxoffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], df_filt['Offset'], statistic='max', bins=[xx,yy])

# %%
fold_plot(ret_maxoffs.statistic.T, file+' - Maximum Offset', binsize_x, binsize_y)

# %%
ret_maxinloffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], abs(df_filt['OffsetY']), statistic='max', bins=[xx,yy])

# %%
fold_plot(ret_maxinloffs.statistic.T, file+' - Maximum Inline Offset', binsize_x, binsize_y)

# %%
ret_mininloffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], abs(df_filt['OffsetY']), statistic='min', bins=[xx,yy])

# %%
fold_plot(ret_mininloffs.statistic.T, file+' - Minimum Inline Offset', binsize_x, binsize_y)

# %%
ret_maxxloffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], abs(df_filt['OffsetX']), statistic='max', bins=[xx,yy])

# %%
fold_plot(ret_maxxloffs.statistic.T, file+' - Maximum Xline Offset', binsize_x, binsize_y)

# %%
ret_minxloffs = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['MidPtY'], abs(df_filt['OffsetX']), statistic='min', bins=[xx,yy])

# %%
fold_plot(ret_minxloffs.statistic.T, file+' - Minimum Xline Offset', binsize_x, binsize_y)

# %%
ret_inlineoffs_count = stats.binned_statistic_2d(df_filt['MidPtX'], df_filt['OffsetY'], None, statistic='count', bins=[xx,offset_bin])

# %%
def fold_plot_offset(data, title, incx, incy):
    data[data==0] = np.nan
    sns.set_style('dark')
    f, ax = plt.subplots(figsize=(18, 12))
    pal = sns.color_palette('Reds')
    x_ticks = np.linspace(0, 240, 7)
    
    #ax = sns.heatmap(data, cmap=pal, linewidths=0.1, cbar_kws={"ticks":x_ticks})
    ax = sns.heatmap(data, cmap=pal, vmin=0, vmax=240, linewidths=0.1, cbar_kws={"ticks":x_ticks})
    plt.xlabel('Bin X (inc: '+ str(incx)+'m)')
    plt.ylabel('Offset class (inc: ' + str(incy) + 'm)')
    plt.title(title);

# %%
fold_plot_offset(ret_inlineoffs_count.statistic.T, file+' - Hits per offset class', binsize_x, offset_binsize)

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4f76a9dad686> in <module>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
x = [0.1, 0.1, 0.1, 0.6]
y = [2.1, 2.6, 2.1, 2.1]
binx = [0.0, 0.5, 1.0, 1.5]
biny = [2.0, 2.5, 3.0]
ret = stats.binned_statistic_2d(x, y, None, 'count', bins=[binx,biny])

# %%
fold_plot(ret.statistic.T)
